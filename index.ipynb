# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()#Your code here

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
c.execute("""select *
                from employees join offices using(officecode) 
                order by firstname, lastname""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]#Your code here
df
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1611     Fixter      Andy      x101
# 1            1143        Bow   Anthony     x5428
# 2            1504      Jones     Barry      x102
# 3            1002     Murphy     Diane     x5800
# 4            1286      Tseng  Foon Yue     x2248
# 5            1323     Vanauf    George     x4102
# 6            1102     Bondur    Gerard     x5408
# 7            1370  Hernandez    Gerard     x2028
# 8            1076   Firrelli      Jeff     x9273
# 9            1188   Firrelli     Julie     x2173
# 10           1501       Bott     Larry     x2311
# 11           1165   Jennings    Leslie     x3291
# 12           1166   Thompson    Leslie     x4065
# 13           1337     Bondur      Loui     x6493
# 14           1621      Nishi      Mami      x101
# 15           1702     Gerard    Martin     x2312
# 16           1056  Patterson      Mary     x4611
# 17           1401   Castillo    Pamela     x2759
# 18           1612      Marsh     Peter      x102
# 19           1216  Patterson     Steve     x4334
# 20           1619       King       Tom      x103
# 21           1088  Patterson   William     x4871
# 22           1625       Kato   Yoshimi      x102
#
#                               email officeCode reportsTo  \
# 0      afixter@classicmodelcars.com          6      1088
# 1         abow@classicmodelcars.com          1      1056
# 2       bjones@classicmodelcars.com          7      1102
# 3      dmurphy@classicmodelcars.com          1
# 4       ftseng@classicmodelcars.com          3      1143
# 5      gvanauf@classicmodelcars.com          3      1143
# 6      gbondur@classicmodelcars.com          4      1056
# 7    ghernande@classicmodelcars.com          4      1102
# 8    jfirrelli@classicmodelcars.com          1      1002
# 9    jfirrelli@classicmodelcars.com          2      1143
# 10       lbott@classicmodelcars.com          7      1102
# 11   ljennings@classicmodelcars.com          1      1143
# 12   lthompson@classicmodelcars.com          1      1143
# 13     lbondur@classicmodelcars.com          4      1102
# 14      mnishi@classicmodelcars.com          5      1056
# 15     mgerard@classicmodelcars.com          4      1102
# 16   mpatterso@classicmodelcars.com          1      1002
# 17   pcastillo@classicmodelcars.com          4      1102
# 18      pmarsh@classicmodelcars.com          6      1088
# 19  spatterson@classicmodelcars.com          2      1143
# 20       tking@classicmodelcars.com          6      1088
# 21  wpatterson@classicmodelcars.com          6      1056
# 22       ykato@classicmodelcars.com          5      1621
#
#                 jobTitle           city             phone  \
# 0              Sales Rep         Sydney   +61 2 9264 2451
# 1     Sales Manager (NA)  San Francisco   +1 650 219 4782
# 2              Sales Rep         London  +44 20 7877 2041
# 3              President  San Francisco   +1 650 219 4782
# 4              Sales Rep            NYC   +1 212 555 3000
# 5              Sales Rep            NYC   +1 212 555 3000
# 6    Sale Manager (EMEA)          Paris   +33 14 723 4404
# 7              Sales Rep          Paris   +33 14 723 4404
# 8           VP Marketing  San Francisco   +1 650 219 4782
# 9              Sales Rep         Boston   +1 215 837 0825
# 10             Sales Rep         London  +44 20 7877 2041
# 11             Sales Rep  San Francisco   +1 650 219 4782
# 12             Sales Rep  San Francisco   +1 650 219 4782
# 13             Sales Rep          Paris   +33 14 723 4404
# 14             Sales Rep          Tokyo   +81 33 224 5000
# 15             Sales Rep          Paris   +33 14 723 4404
# 16              VP Sales  San Francisco   +1 650 219 4782
# 17             Sales Rep          Paris   +33 14 723 4404
# 18             Sales Rep         Sydney   +61 2 9264 2451
# 19             Sales Rep         Boston   +1 215 837 0825
# 20             Sales Rep         Sydney   +61 2 9264 2451
# 21  Sales Manager (APAC)         Sydney   +61 2 9264 2451
# 22             Sales Rep          Tokyo   +81 33 224 5000
#
#                 addressLine1 addressLine2       state    country postalCode  \
# 0      5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 1          100 Market Street    Suite 300          CA        USA      94080
# 2        25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 3          100 Market Street    Suite 300          CA        USA      94080
# 4       523 East 53rd Street      apt. 5A          NY        USA      10022
# 5       523 East 53rd Street      apt. 5A          NY        USA      10022
# 6   43 Rue Jouffroy D'abbans                              France      75017
# 7   43 Rue Jouffroy D'abbans                              France      75017
# 8          100 Market Street    Suite 300          CA        USA      94080
# 9           1550 Court Place    Suite 102          MA        USA      02107
# 10       25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 11         100 Market Street    Suite 300          CA        USA      94080
# 12         100 Market Street    Suite 300          CA        USA      94080
# 13  43 Rue Jouffroy D'abbans                              France      75017
# 14               4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 15  43 Rue Jouffroy D'abbans                              France      75017
# 16         100 Market Street    Suite 300          CA        USA      94080
# 17  43 Rue Jouffroy D'abbans                              France      75017
# 18     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 19          1550 Court Place    Suite 102          MA        USA      02107
# 20     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 21     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 22               4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
#
#    territory
# 0       APAC
# 1         NA
# 2       EMEA
# 3         NA
# 4         NA
# 5         NA
# 6       EMEA
# 7       EMEA
# 8         NA
# 9         NA
# 10      EMEA
# 11        NA
# 12        NA
# 13      EMEA
# 14     Japan
# 15      EMEA
# 16        NA
# 17      EMEA
# 18      APAC
# 19        NA
# 20      APAC
# 21      APAC
# 22     Japan

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
c.execute("""SELECT contactfirstname, contaclastname
                FROM customers
                JOIN orders
                USING (customernumber)""")# Your code here
# Out:
# OperationalErrorTraceback (most recent call last)
# <ipython-input-6-ecc50639a6ae> in <module>()
#       2                 FROM customers
#       3                 JOIN orders
# ----> 4                 USING (customernumber)""")# Your code here
#
# OperationalError: no such column: firstname

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
